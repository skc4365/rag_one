# %%
# !pip --version
# Out:
# pip 26.2.1 from E:\hanwh2609\rag_one\.venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install dotenv
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pip install

# %%
# 문서로더
# 가장 보편적인 PyPDF 기반 로더 (pypdf 패키지 필요)
from langchain_community.document_loaders import PyPDFLoader

# PDF 디렉터리 전체 로드
from langchain_community.document_loaders import PyPDFDirectoryLoader

# 빠른 속도를 원할 때 (PyMuPDF / fitz 패키지 필요)
from langchain_community.document_loaders import PyMuPDFLoader

# %%
from langchain_core.documents import Document

# %%
document = Document(page_content="안녕하세요! 랭체인 도큐먼트")

# %%
document.__dict__
# Out:
# {'id': None,
#  'metadata': {},
#  'page_content': '안녕하세요! 랭체인 도큐먼트',
#  'type': 'Document'}

# %%
document.metadata["source"] = "skc소스"
document.metadata["page"] = 1
document.metadata["author"] = "어쩌구~저자"

document.metadata
# Out:
# {'source': 'skc소스', 'page': 1, 'author': '어쩌구~저자'}

# %%
document.__dict__
# Out:
# {'id': None,
#  'metadata': {'source': 'skc소스', 'page': 1, 'author': '어쩌구~저자'},
#  'page_content': '안녕하세요! 랭체인 도큐먼트',
#  'type': 'Document'}
