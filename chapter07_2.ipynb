# %% [markdown]
# ### 04. 직렬화와 역질렬화로 모델 저장 및 로드하기

# %%
# !pip --version
# Out:
# pip 25.0.1 from D:\skc0902\ex0917\.venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install dotenv
from dotenv import load_dotenv

# .env파일에 설정된 보안정보를 읽기.
load_dotenv()
# Out:
# True
